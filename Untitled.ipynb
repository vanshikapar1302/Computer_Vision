# %%
# !pip install --proxy "" opencv-python --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org

# %%
import cv2 #cv2 is the standard library alias used for openCV in Python, have all the functions for major image processing

# %%
img=cv2.imread("nature.png")

# %%
img.shape

# %%
type(img)

# %%
img

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imshow("nature.png", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Convert to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray MSD", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Pixel Manipulation
#ROT-Region of interest
# Drawing shape and text
